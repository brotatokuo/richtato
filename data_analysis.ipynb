# %%
from richtato.utilities.postgres.pg_client import PostgresClient

pg_client = PostgresClient()
df = pg_client.get_expense_df(2)
df

# %%
from richtato.apps.expense.utils import sankey_by_category
sankey_by_category(df)
