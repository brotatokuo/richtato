# %%
import os
import django

os.environ.setdefault("DJANGO_SETTINGS_MODULE", "richtato.richtato.settings")
django.setup()

from asgiref.sync import sync_to_async
from richtato.apps.richtato_user.models import User

async def get_user():
    user = await sync_to_async(User.objects.get)(username="admin")
    return user

user = await get_user()

# %%
from bank_of_america import BankOfAmericaCards
from richtato.apps.richtato_user.models import User
path = r"C:\Users\Alan\Downloads\February2025_8737.csv"

bofa = BankOfAmericaCards.from_file(user, "Custom Cash", path)
df = bofa.format()
df

# %%
path = r"C:\Users\Alan\Downloads\activity.xlsx"
from american_express import AmericanExpressCards

amex = AmericanExpressCards.from_file(user, "Platinum", path)
amex_df = amex.format()
amex_df
# Out:
# c:\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#           Date                                 Description   Amount      Card  \
# 0   2025-02-12                  MOBILE PAYMENT - THANK YOU  -395.78  Platinum
# 1   2025-02-12                     AMAZON MARKEPLACE NA PA   193.83  Platinum
# 2   2025-02-14  GEN KOREAN BBQ FREMOCERRITOS            CA    59.25  Platinum
# 3   2025-02-16  HOMEOWNERS INSURANCEBOSTON              MA  1858.00  Platinum
# 4   2025-02-20                  MOBILE PAYMENT - THANK YOU -2111.08  Platinum
# 5   2025-02-22  AMAZON MARKETPLACE NAMZN.COM/BILL       WA    -9.91  Platinum
# 6   2025-02-22  AMAZON MARKETPLACE NAMZN.COM/BILL       WA   -11.01  Platinum
# 7   2025-02-24  AplPay THE HOME DEPOSUNNYVALE           CA   162.60  Platinum
# 8   2025-02-26                                        UBER   109.11  Platinum
# 9   2025-02-26                       AMEX RIDESHARE CREDIT   -10.00  Platinum
# 10  2025-03-03  AMAZON MARKETPLACE NAMZN.COM/BILL       WA   -19.68  Platinum
# 11  2025-03-03  AMAZON MARKETPLACE NAMZN.COM/BILL       WA   -38.58  Platinum
# 12  2025-03-03  AMAZON MARKETPLACE NAMZN.COM/BILL       WA   -38.58  Platinum
# 13  2025-03-03                  MOBILE PAYMENT - THANK YOU  -240.79  Platinum
# 14  2025-03-04  AMAZON MARKETPLACE NAMZN.COM/BILL       WA   -27.55  Platinum
# 15  2025-03-04  AMAZON MARKETPLACE NAMZN.COM/BILL       WA   -30.86  Platinum
# 16  2025-03-04  AMAZON MARKETPLACE NAMZN.COM/BILL       WA   -38.58  Platinum
# 17  2025-03-07  BURBANK PET HOSPITALSAN JOSE            CA    57.75  Platinum
# 18  2025-03-13                      RENEWAL MEMBERSHIP FEE   350.00  Platinum
#
#            Category
# 0          Payments
# 1   Online Shopping
# 2            Dining
# 3           Housing
# 4          Payments
# 5   Online Shopping
# 6   Online Shopping
# 7              None
# 8            Travel
# 9            Travel
# 10  Online Shopping
# 11  Online Shopping
# 12  Online Shopping
# 13         Payments
# 14  Online Shopping
# 15  Online Shopping
# 16  Online Shopping
# 17              Pet
# 18    Subscriptions

# %%
file_path = r"C:\Users\Alan\Downloads\Annual Account Summary (2024).CSV"
from citi import CitiCards
citi = CitiCards.from_file(user, "Double Cash", file_path)
citi_df = citi.format()
citi_df
# Out:
#            Date                            Description   Amount         Card  \
# 0    2024-01-01   SLURPING TURTLE - ANN 630-7888805 MI    98.74  Double Cash
# 1    2024-01-03         COSTCO WHSE #1106 ANN ARBOR MI    24.48  Double Cash
# 2    2024-01-06         COSTCO WHSE #1106 ANN ARBOR MI   162.00  Double Cash
# 3    2024-01-06           COSTCO WHSE #1107 CHICAGO IL   118.01  Double Cash
# 4    2024-01-08         COSTCO WHSE #1106 ANN ARBOR MI    67.28  Double Cash
# ..          ...                                    ...      ...          ...
# 232  2024-12-19         COSTCO WHSE #0423 SUNNYVALE CA   395.75  Double Cash
# 233  2024-12-20   LAZ PARKING M18387-WC SANTA CLARA CA     2.00  Double Cash
# 234  2024-12-23   LAZ PARKING M18387-WC SANTA CLARA CA     4.00  Double Cash
# 235  2024-12-24           COSTCO WHSE #0778 FREMONT CA   120.71  Double Cash
# 236  2024-12-31  EXPEDIA 72997339112892 EXPEDIA.COM WA  3350.75  Double Cash
#
#     Category
# 0       None
# 1     Costco
# 2     Costco
# 3     Costco
# 4     Costco
# ..       ...
# 232   Costco
# 233      Car
# 234      Car
# 235   Costco
# 236   Travel
#
# [237 rows x 5 columns]
