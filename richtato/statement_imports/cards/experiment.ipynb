# %%
path = r"C:\Users\Alan\Downloads\February2025_8737.csv"

from bank_of_america import BankOfAmericaCards

bofa = BankOfAmericaCards("Custom Cash", path)
df = bofa.format()
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 5
#       1 path = r"C:\Users\Alan\Downloads\February2025_8737.csv"
#       3 from bank_of_america import BankOfAmericaCards
# ----> 5 bofa = BankOfAmericaCards("Custom Cash", path)
#       6 df = bofa.format()
#       7 df
#
# File ~\OneDrive\Desktop\Richtato\richtato\statement_imports\cards\card_canonicalizer.py:22, in CardCanonicalizer.__init__(self, card_name, df)
#      20 self.formatted_df = pd.DataFrame()
#      21 self.output_columns = ["Card", "Date", "Description", "Amount", "Category"]
# ---> 22 self.check_input_format()
#
# File ~\OneDrive\Desktop\Richtato\richtato\statement_imports\cards\card_canonicalizer.py:61, in CardCanonicalizer.check_input_format(self)
#      57 def check_input_format(self):
#      58     """
#      59     Checks if the input DataFrame has the required format.
#      60     """
# ---> 61     if self.df.columns.tolist() != self.input_columns:
#      62         raise ValueError(
#      63             f"Input DataFrame is not the expected format. Expected columns: {self.input_columns}"
#      64         )
#
# AttributeError: 'str' object has no attribute 'columns'
